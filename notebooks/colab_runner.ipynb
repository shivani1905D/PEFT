# %% [markdown]
# # Colab Runner — PEFT + Quantization Benchmark
#
# This notebook only orchestrates: clone repo, install deps, run scripts. All the actual logic
# (data loading, model training, metrics) lives in `src/` on GitHub, not in this notebook.
#
# **Runtime:** `Runtime > Change runtime type > T4 GPU` before running anything below.

# %% [markdown]
# ## 1. Clone + install (run once per fresh runtime)

# %%
REPO_URL = "https://github.com/YOUR_USERNAME/peft-quant-benchmark.git"  # <-- edit this

# !git clone {REPO_URL}
# %cd peft-quant-benchmark
# !pip install -q -r requirements.txt
print("\nNow: Runtime > Restart session, then continue from Cell 2 below.")

# %% [markdown]
# ## 2. After restarting — just cd back in (no reinstall needed)

# %%
# %cd peft-quant-benchmark
# !nvidia-smi --query-gpu=name,memory.total --format=csv

# %% [markdown]
# ## 3. Sanity check — one method

# %%
# !python src/train.py --method lora --model_name Qwen/Qwen2.5-1.5B --label_col label_domain

# %% [markdown]
# ## 4. Full run — all 6 methods, small model, coarse labels

# %%
# !python src/run_all.py --model_name Qwen/Qwen2.5-1.5B --label_col label_domain

# %% [markdown]
# ## 5. Full run — larger model

# %%
# !python src/run_all.py --model_name Qwen/Qwen2.5-7B --label_col label_domain

# %% [markdown]
# ## 6. Hard-mode run — fine-grained (134-class) labels

# %%
# !python src/run_all.py --model_name Qwen/Qwen2.5-1.5B --label_col label_fine

# %% [markdown]
# ## 7. Push results back to GitHub

# %%
# !git add results/
# !git commit -m "Add benchmark results"
# !git push

# %% [markdown]
# ## 8. Inspect results

# %%
import pandas as pd
df = pd.read_csv("results/results_Qwen_Qwen2.5-1.5B_label_domain.csv")
df
